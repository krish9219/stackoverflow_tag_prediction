# %%
import pandas as pd
import warnings
import numpy as np
import seaborn as sns
from wordcloud import WordCloud
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
import lxml
import re
from nltk.corpus import stopwords
from nltk.tokenize import ToktokTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.metrics import f1_score,precision_score,recall_score
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')

# %%
questions = pd.read_csv("Questions.csv", encoding="ISO-8859-1")
tags = pd.read_csv("Tags.csv", encoding="ISO-8859-1", dtype={'Tag': str})

# %%
questions.head()
# Out:
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                Title  \
# 0  SQLStatement.execute() - multiple queries in o...
# 1  Good branching and merging tutorials for Torto...
# 2                                  ASP.NET Site Maps
# 3                 Function for creating color wheels
# 4  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...

# %%
questions.shape, tags.shape
# Out:
# ((1264216, 7), (3750994, 2))

# %%
tags.head()
# Out:
#    Id             Tag
# 0  80            flex
# 1  80  actionscript-3
# 2  80             air
# 3  90             svn
# 4  90     tortoisesvn

# %%
tags['Tag'] = tags['Tag'].astype('str')

# %%
group_tags = tags.groupby('Id')['Tag'].apply(lambda x: ' '.join(x))

# %%
group_tags.head()
# Out:
# Id
# 80                            flex actionscript-3 air
# 90       svn tortoisesvn branch branching-and-merging
# 120                               sql asp.net sitemap
# 180    algorithm language-agnostic colors color-space
# 260           c# .net scripting compiler-construction
# Name: Tag, dtype: object

# %%
group_tags.reset_index()
group_tags = pd.DataFrame({'Id':group_tags.index, 'Tag':group_tags.values})
group_tags.head()
# Out:
#     Id                                             Tag
# 0   80                         flex actionscript-3 air
# 1   90    svn tortoisesvn branch branching-and-merging
# 2  120                             sql asp.net sitemap
# 3  180  algorithm language-agnostic colors color-space
# 4  260         c# .net scripting compiler-construction

# %%
group_tags.shape
# Out:
# (1264216, 2)

# %%
questions.drop(['OwnerUserId','CreationDate', 'ClosedDate'], axis = 1, inplace =True)

# %%
data = questions.merge(group_tags, on = 'Id')

# %%
data.head()
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                               Tag
# 0                         flex actionscript-3 air
# 1    svn tortoisesvn branch branching-and-merging
# 2                             sql asp.net sitemap
# 3  algorithm language-agnostic colors color-space
# 4         c# .net scripting compiler-construction

# %%
new_data = data[data['Score']>10]

# %%
new_data.head()
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                               Tag
# 0                         flex actionscript-3 air
# 1    svn tortoisesvn branch branching-and-merging
# 2                             sql asp.net sitemap
# 3  algorithm language-agnostic colors color-space
# 4         c# .net scripting compiler-construction

# %%
data.shape, new_data.shape
# Out:
# ((1264216, 5), (32604, 5))

# %%
new_data['Tag'] = new_data['Tag'].apply(lambda x: x.split())

# %%
new_data.head()
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                                  Tag
# 0                        [flex, actionscript-3, air]
# 1  [svn, tortoisesvn, branch, branching-and-merging]
# 2                            [sql, asp.net, sitemap]
# 3  [algorithm, language-agnostic, colors, color-s...
# 4       [c#, .net, scripting, compiler-construction]

# %%
# all_tags = [x for i in new_data['Tag'].values for x in i]

# %%
# all_tags

# %%
vectorizer = CountVectorizer( tokenizer=lambda x: x.split())

# %%
tags_counter = vectorizer.fit_transform(data['Tag'])

# %%
tags_counter.shape[0], tags_counter.shape[1]
# Out:
# (1264216, 37035)

# %%
tags_counter
# Out:
# <1264216x37035 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3750993 stored elements in Compressed Sparse Row format>

# %%
new_data['counts'] = [len(count) for count in new_data['Tag']]

# %%
new_data.head()
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                                  Tag  counts
# 0                        [flex, actionscript-3, air]       3
# 1  [svn, tortoisesvn, branch, branching-and-merging]       4
# 2                            [sql, asp.net, sitemap]       3
# 3  [algorithm, language-agnostic, colors, color-s...       4
# 4       [c#, .net, scripting, compiler-construction]       4

# %%
flat_tags = vectorizer.get_feature_names()
flat_tags[:10]
# Out:
# ['.a',
#  '.app',
#  '.aspxauth',
#  '.bash-profile',
#  '.class-file',
#  '.doc',
#  '.emf',
#  '.git-info-grafts',
#  '.hgtags',
#  '.htaccess']

# %%
freqs = tags_counter.sum(axis=0).A1
result = list(zip(flat_tags, freqs))
columns = ['Tags', 'Counts']
tag_df = pd.DataFrame(result, columns=columns)
tag_df.head()
# Out:
#             Tags  Counts
# 0             .a      13
# 1           .app      14
# 2      .aspxauth       6
# 3  .bash-profile      46
# 4    .class-file      19

# %%
# Sorting tag data frame with Counts to know most repeating tags

tag_df.sort_values(['Counts'], ascending=False, inplace=True)

# %%
freq_tags = tag_df[tag_df['Counts']>47000]

# %%
freq_tags.head(20)
# Out:
#              Tags  Counts
# 16121  javascript  124155
# 16020        java  115212
# 4301           c#  101186
# 24212         php   98808
# 979       android   90659
# 16611      jquery   78542
# 25713      python   64601
# 14180        html   58976
# 4311          c++   47591
# 15565         ios   47009

# %%
most_common_words = freq_tags['Tags'].values

# %%
frequencies_words = most_common_words
tags_features = [word for word in frequencies_words]

# %%
len(tags_features)
# Out:
# 10

# %%
# new_data.drop(columns=['Id', 'Score'], inplace=True)
print(tags_features)
# Out:
# ['javascript', 'java', 'c#', 'php', 'android', 'jquery', 'python', 'html', 'c++', 'ios']

# %%
new_df = new_data

# %%
def most_common(tags):
    """Function to check if tag is in most common tag list"""
    tags_filtered = []
    for i in range(0, len(tags)):
        if tags[i] in tags_features:
            tags_filtered.append(tags[i])
    return tags_filtered

# %%
new_df.head()
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body  \
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...
#
#                                                  Tag  counts
# 0                        [flex, actionscript-3, air]       3
# 1  [svn, tortoisesvn, branch, branching-and-merging]       4
# 2                            [sql, asp.net, sitemap]       3
# 3  [algorithm, language-agnostic, colors, color-s...       4
# 4       [c#, .net, scripting, compiler-construction]       4

# %%
# Change Tags column into None for questions that don't have a most common tag
new_df['Tag'] = new_df['Tag'].apply(lambda x: most_common(x))
new_df['Tag'] = new_df['Tag'].apply(lambda x: x if len(x)>0 else None)

# %%
new_df.head()
# Out:
#     Id  Score                                              Title  \
# 0   80     26  SQLStatement.execute() - multiple queries in o...
# 1   90    144  Good branching and merging tutorials for Torto...
# 2  120     21                                  ASP.NET Site Maps
# 3  180     53                 Function for creating color wheels
# 4  260     49  Adding scripting functionality to .NET applica...
#
#                                                 Body   Tag  counts
# 0  <p>I've written a database generation script i...  None       3
# 1  <p>Are there any really good tutorials explain...  None       4
# 2  <p>Has anyone got experience creating <strong>...  None       3
# 3  <p>This is something I've pseudo-solved many t...  None       4
# 4  <p>I have a little game written in C#. It uses...  [c#]       4

# %%
new_df.dropna(subset=['Tag'], inplace=True)
new_df.drop(['counts'], axis = 1, inplace=True)
new_df.shape
# Out:
# (17897, 5)

# %%
new_df.head()
# Out:
#       Id  Score                                              Title  \
# 4    260     49  Adding scripting functionality to .NET applica...
# 5    330     29          Should I use nested classes in this case?
# 8    650     79                Automatically update version number
# 10   930     28  How do I connect to a database and loop over a...
# 11  1010     14  How to get the value of built, encoded ViewState?
#
#                                                  Body    Tag
# 4   <p>I have a little game written in C#. It uses...   [c#]
# 5   <p>I am working on a collection of classes use...  [c++]
# 8   <p>I would like the version property of my app...   [c#]
# 10  <p>What's the simplest way to connect and quer...   [c#]
# 11  <p>I need to grab the base64-encoded represent...   [c#]

# %% [markdown]
# ## Preprocess Data ##
#
# #### Remove special characters from title and body##
# #### Remove stop words###
# #### Remove HTML tags###
# #### Convert characters to lowercase###
# #### Lemmatize the words###

# %%
new_df['Body'] = new_df['Body'].apply(lambda x: BeautifulSoup(x, "lxml").get_text())

# %%
new_df.head()
# Out:
#       Id  Score                                              Title  \
# 4    260     49  Adding scripting functionality to .NET applica...
# 5    330     29          Should I use nested classes in this case?
# 8    650     79                Automatically update version number
# 10   930     28  How do I connect to a database and loop over a...
# 11  1010     14  How to get the value of built, encoded ViewState?
#
#                                                  Body    Tag
# 4   I have a little game written in C#. It uses a ...   [c#]
# 5   I am working on a collection of classes used f...  [c++]
# 8   I would like the version property of my applic...   [c#]
# 10  What's the simplest way to connect and query a...   [c#]
# 11  I need to grab the base64-encoded representati...   [c#]

# %%
token = ToktokTokenizer()
lemma = WordNetLemmatizer()
stop = set(stopwords.words("english"))

# %%
new_df['Body'] = new_df['Body'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
new_df['Body'] = new_df['Body'].apply(lambda x: re.sub('[^\w\s][!"$%&\'()*,./:;<=>?@[\\]^_`{|}~]', '', x))
new_df['Body'] = new_df['Body'].apply(lambda x: ' '.join(x for x in x.split() if x not in stop))
new_df['Body'] = new_df['Body'].apply(lambda x: ' '.join(lemma.lemmatize(word) for word in x.split()))

# %%
new_df.head()
# Out:
#       Id  Score                                              Title  \
# 4    260     49  Adding scripting functionality to .NET applica...
# 5    330     29          Should I use nested classes in this case?
# 8    650     79                Automatically update version number
# 10   930     28  How do I connect to a database and loop over a...
# 11  1010     14  How to get the value of built, encoded ViewState?
#
#                                                  Body    Tag
# 4   little game written c us database back-end. tr...   [c#]
# 5   working collection class used video playback r...  [c++]
# 8   would like version property application increm...   [c#]
# 10  what's simplest way connect query database set...   [c#]
# 11  need grab base64-encoded representation viewst...   [c#]

# %%
new_df['Title'] = new_df['Title'].apply(lambda x: ' '.join(x.lower() for x in x.split()))
new_df['Title'] = new_df['Title'].apply(lambda x: re.sub('[^\w\s][!"$%&\'()*,./:;<=>?@[\\]^_`{|}~]', '', x))
new_df['Title'] = new_df['Title'].apply(lambda x: ' '.join(x for x in x.split() if x not in stop))
new_df['Title'] = new_df['Title'].apply(lambda x: ' '.join(lemma.lemmatize(word) for word in x.split()))
new_df['Title'] = new_df['Title'].apply(lambda x: ' '.join(x.split()*3))

# %%
new_df.head()
# Out:
#       Id  Score                                              Title  \
# 4    260     49  adding scripting functionality .net applicatio...
# 5    330     29  use nested class case? use nested class case? ...
# 8    650     79  automatically update version number automatica...
# 10   930     28  connect database loop recordset c connect data...
# 11  1010     14  get value built, encoded viewstate? get value ...
#
#                                                  Body    Tag
# 4   little game written c us database back-end. tr...   [c#]
# 5   working collection class used video playback r...  [c++]
# 8   would like version property application increm...   [c#]
# 10  what's simplest way connect query database set...   [c#]
# 11  need grab base64-encoded representation viewst...   [c#]

# %%
new_df['modified_Body'] = new_df["Body"].map(str) + ' ' + new_df["Title"]

# %%
length = [len(word_tokenize(x)) for x in new_df['modified_Body']]

length
# Out:
# [135,
#  125,
#  93,
#  25,
#  83,
#  56,
#  73,
#  49,
#  40,
#  104,
#  161,
#  42,
#  52,
#  96,
#  42,
#  53,
#  63,
#  99,
#  131,
#  140,
#  43,
#  179,
#  127,
#  39,
#  84,
#  158,
#  50,
#  71,
#  73,
#  140,
#  52,
#  59,
#  162,
#  260,
#  98,
#  42,
#  86,
#  28,
#  57,
#  76,
#  348,
#  80,
#  90,
#  34,
#  31,
#  41,
#  28,
#  61,
#  31,
#  77,
#  77,
#  138,
#  47,
#  91,
#  60,
#  69,
#  92,
#  38,
#  35,
#  177,
#  176,
#  41,
#  83,
#  53,
#  32,
#  41,
#  57,
#  110,
#  94,
#  111,
#  235,
#  43,
#  65,
#  48,
#  39,
#  98,
#  130,
#  62,
#  84,
#  45,
#  81,
#  54,
#  56,
#  108,
#  86,
#  147,
#  121,
#  414,
#  59,
#  111,
#  93,
#  70,
#  88,
#  38,
#  90,
#  66,
#  39,
#  755,
#  115,
#  88,
#  82,
#  106,
#  93,
#  97,
#  45,
#  91,
#  79,
#  49,
#  47,
#  39,
#  104,
#  117,
#  116,
#  42,
#  160,
#  69,
#  95,
#  190,
#  201,
#  92,
#  36,
#  182,
#  162,
#  58,
#  143,
#  294,
#  35,
#  58,
#  29,
#  49,
#  70,
#  24,
#  30,
#  72,
#  77,
#  67,
#  100,
#  68,
#  30,
#  22,
#  57,
#  66,
#  24,
#  56,
#  33,
#  41,
#  83,
#  86,
#  56,
#  125,
#  350,
#  57,
#  38,
#  124,
#  223,
#  62,
#  52,
#  97,
#  56,
#  45,
#  27,
#  128,
#  104,
#  45,
#  116,
#  62,
#  72,
#  50,
#  248,
#  44,
#  228,
#  71,
#  49,
#  41,
#  48,
#  178,
#  44,
#  189,
#  40,
#  29,
#  288,
#  32,
#  122,
#  321,
#  30,
#  87,
#  53,
#  45,
#  34,
#  188,
#  41,
#  197,
#  26,
#  65,
#  46,
#  19,
#  41,
#  114,
#  45,
#  308,
#  208,
#  151,
#  33,
#  136,
#  45,
#  74,
#  81,
#  211,
#  42,
#  120,
#  35,
#  58,
#  234,
#  40,
#  64,
#  62,
#  95,
#  31,
#  51,
#  61,
#  36,
#  99,
#  37,
#  77,
#  201,
#  66,
#  105,
#  86,
#  118,
#  140,
#  131,
#  139,
#  114,
#  123,
#  54,
#  39,
#  33,
#  436,
#  26,
#  60,
#  153,
#  55,
#  104,
#  60,
#  203,
#  70,
#  124,
#  93,
#  135,
#  7,
#  108,
#  88,
#  27,
#  57,
#  111,
#  72,
#  85,
#  35,
#  62,
#  94,
#  37,
#  74,
#  99,
#  23,
#  41,
#  34,
#  36,
#  27,
#  32,
#  66,
#  49,
#  62,
#  104,
#  415,
#  44,
#  141,
#  20,
#  57,
#  105,
#  37,
#  58,
#  286,
#  86,
#  74,
#  112,
#  58,
#  57,
#  85,
#  76,
#  69,
#  137,
#  71,
#  167,
#  39,
#  42,
#  54,
#  58,
#  46,
#  43,
#  130,
#  41,
#  65,
#  181,
#  70,
#  185,
#  117,
#  45,
#  56,
#  62,
#  77,
#  78,
#  163,
#  82,
#  75,
#  70,
#  83,
#  55,
#  41,
#  56,
#  29,
#  208,
#  105,
#  77,
#  135,
#  65,
#  130,
#  65,
#  32,
#  86,
#  88,
#  99,
#  67,
#  70,
#  110,
#  74,
#  184,
#  51,
#  147,
#  43,
#  132,
#  95,
#  46,
#  82,
#  92,
#  122,
#  136,
#  126,
#  103,
#  55,
#  87,
#  24,
#  21,
#  46,
#  61,
#  56,
#  39,
#  115,
#  19,
#  101,
#  136,
#  270,
#  196,
#  112,
#  94,
#  344,
#  77,
#  53,
#  30,
#  125,
#  35,
#  218,
#  47,
#  114,
#  46,
#  213,
#  64,
#  27,
#  32,
#  55,
#  94,
#  73,
#  528,
#  104,
#  97,
#  146,
#  35,
#  25,
#  63,
#  41,
#  50,
#  70,
#  67,
#  183,
#  166,
#  67,
#  77,
#  86,
#  40,
#  27,
#  69,
#  45,
#  97,
#  114,
#  35,
#  92,
#  103,
#  27,
#  130,
#  113,
#  78,
#  137,
#  44,
#  74,
#  107,
#  22,
#  35,
#  76,
#  333,
#  115,
#  113,
#  56,
#  72,
#  34,
#  58,
#  199,
#  62,
#  74,
#  161,
#  50,
#  89,
#  104,
#  97,
#  41,
#  49,
#  97,
#  84,
#  99,
#  54,
#  130,
#  113,
#  116,
#  453,
#  92,
#  79,
#  66,
#  127,
#  147,
#  98,
#  125,
#  212,
#  34,
#  67,
#  89,
#  79,
#  94,
#  70,
#  33,
#  78,
#  99,
#  47,
#  113,
#  83,
#  83,
#  106,
#  31,
#  48,
#  125,
#  81,
#  32,
#  38,
#  163,
#  129,
#  226,
#  252,
#  110,
#  57,
#  75,
#  46,
#  54,
#  415,
#  57,
#  115,
#  32,
#  116,
#  116,
#  41,
#  112,
#  75,
#  122,
#  55,
#  55,
#  58,
#  26,
#  102,
#  21,
#  33,
#  51,
#  46,
#  62,
#  59,
#  37,
#  44,
#  91,
#  42,
#  85,
#  39,
#  117,
#  254,
#  110,
#  72,
#  104,
#  47,
#  162,
#  76,
#  69,
#  74,
#  51,
#  41,
#  40,
#  119,
#  154,
#  149,
#  38,
#  57,
#  107,
#  204,
#  197,
#  66,
#  1542,
#  44,
#  47,
#  96,
#  30,
#  150,
#  27,
#  51,
#  125,
#  160,
#  266,
#  197,
#  285,
#  181,
#  189,
#  73,
#  81,
#  77,
#  121,
#  204,
#  54,
#  49,
#  37,
#  46,
#  124,
#  128,
#  26,
#  96,
#  48,
#  30,
#  163,
#  33,
#  277,
#  47,
#  68,
#  116,
#  38,
#  55,
#  72,
#  66,
#  62,
#  306,
#  94,
#  41,
#  221,
#  99,
#  21,
#  41,
#  124,
#  91,
#  83,
#  46,
#  45,
#  100,
#  109,
#  98,
#  135,
#  44,
#  167,
#  95,
#  78,
#  61,
#  52,
#  50,
#  65,
#  180,
#  92,
#  42,
#  83,
#  17,
#  96,
#  56,
#  40,
#  140,
#  46,
#  68,
#  53,
#  72,
#  43,
#  70,
#  146,
#  88,
#  104,
#  38,
#  108,
#  44,
#  68,
#  76,
#  142,
#  73,
#  59,
#  76,
#  50,
#  122,
#  113,
#  179,
#  200,
#  53,
#  62,
#  55,
#  142,
#  192,
#  65,
#  79,
#  320,
#  217,
#  109,
#  116,
#  70,
#  93,
#  26,
#  69,
#  37,
#  50,
#  53,
#  56,
#  247,
#  26,
#  111,
#  105,
#  34,
#  50,
#  40,
#  44,
#  39,
#  84,
#  15,
#  39,
#  42,
#  34,
#  36,
#  189,
#  101,
#  82,
#  48,
#  64,
#  187,
#  84,
#  24,
#  55,
#  132,
#  59,
#  56,
#  57,
#  73,
#  236,
#  143,
#  52,
#  27,
#  114,
#  112,
#  61,
#  99,
#  24,
#  61,
#  27,
#  129,
#  61,
#  42,
#  171,
#  46,
#  128,
#  17,
#  105,
#  619,
#  150,
#  81,
#  47,
#  55,
#  35,
#  128,
#  42,
#  54,
#  121,
#  126,
#  122,
#  97,
#  67,
#  88,
#  113,
#  74,
#  32,
#  38,
#  48,
#  152,
#  52,
#  53,
#  42,
#  53,
#  38,
#  89,
#  38,
#  107,
#  42,
#  107,
#  65,
#  43,
#  174,
#  142,
#  182,
#  52,
#  275,
#  39,
#  201,
#  67,
#  124,
#  33,
#  128,
#  45,
#  65,
#  95,
#  107,
#  92,
#  51,
#  92,
#  80,
#  120,
#  230,
#  43,
#  57,
#  164,
#  39,
#  103,
#  54,
#  97,
#  164,
#  56,
#  143,
#  181,
#  56,
#  67,
#  97,
#  28,
#  130,
#  19,
#  204,
#  26,
#  35,
#  73,
#  110,
#  25,
#  133,
#  25,
#  198,
#  43,
#  180,
#  157,
#  31,
#  58,
#  73,
#  52,
#  150,
#  24,
#  154,
#  118,
#  97,
#  460,
#  32,
#  381,
#  54,
#  34,
#  193,
#  99,
#  181,
#  70,
#  73,
#  133,
#  80,
#  161,
#  153,
#  46,
#  34,
#  96,
#  82,
#  56,
#  82,
#  133,
#  56,
#  105,
#  127,
#  57,
#  24,
#  54,
#  97,
#  55,
#  25,
#  124,
#  98,
#  135,
#  27,
#  58,
#  87,
#  113,
#  135,
#  36,
#  52,
#  49,
#  158,
#  188,
#  115,
#  444,
#  211,
#  37,
#  103,
#  40,
#  40,
#  48,
#  74,
#  86,
#  108,
#  93,
#  47,
#  292,
#  583,
#  70,
#  177,
#  182,
#  72,
#  56,
#  493,
#  38,
#  48,
#  30,
#  111,
#  92,
#  46,
#  293,
#  148,
#  187,
#  31,
#  35,
#  35,
#  94,
#  64,
#  77,
#  91,
#  87,
#  113,
#  65,
#  152,
#  47,
#  103,
#  45,
#  305,
#  35,
#  41,
#  117,
#  227,
#  23,
#  98,
#  80,
#  65,
#  60,
#  49,
#  62,
#  72,
#  122,
#  20,
#  387,
#  45,
#  81,
#  94,
#  89,
#  86,
#  42,
#  227,
#  50,
#  56,
#  108,
#  296,
#  24,
#  45,
#  62,
#  32,
#  468,
#  67,
#  24,
#  57,
#  74,
#  48,
#  118,
#  266,
#  70,
#  109,
#  50,
#  92,
#  69,
#  101,
#  117,
#  83,
#  87,
#  120,
#  163,
#  301,
#  150,
#  77,
#  50,
#  50,
#  75,
#  208,
#  79,
#  170,
#  71,
#  145,
#  63,
#  243,
#  40,
#  16,
#  80,
#  141,
#  16,
#  22,
#  131,
#  103,
#  25,
#  28,
#  113,
#  73,
#  58,
#  35,
#  104,
#  60,
#  34,
#  164,
#  47,
#  220,
#  61,
#  71,
#  21,
#  129,
#  172,
#  192,
#  105,
#  71,
#  61,
#  97,
#  72,
#  101,
#  163,
#  132,
#  71,
#  96,
#  163,
#  56,
#  42,
#  135,
#  106,
#  184,
#  128,
#  58,
#  28,
#  103,
#  184,
#  61,
#  41,
#  194,
#  32,
#  70,
#  59,
#  105,
#  100,
#  59,
#  93,
#  42,
#  75,
#  17,
#  162,
#  167,
#  58,
#  44,
#  117,
#  178,
#  ...]

# %%
new_df.head()
# Out:
#       Id  Score                                              Title  \
# 4    260     49  adding scripting functionality .net applicatio...
# 5    330     29  use nested class case? use nested class case? ...
# 8    650     79  automatically update version number automatica...
# 10   930     28  connect database loop recordset c connect data...
# 11  1010     14  get value built, encoded viewstate? get value ...
#
#                                                  Body    Tag  \
# 4   little game written c us database back-end. tr...   [c#]
# 5   working collection class used video playback r...  [c++]
# 8   would like version property application increm...   [c#]
# 10  what's simplest way connect query database set...   [c#]
# 11  need grab base64-encoded representation viewst...   [c#]
#
#                                         modified_Body
# 4   little game written c us database back-end. tr...
# 5   working collection class used video playback r...
# 8   would like version property application increm...
# 10  what's simplest way connect query database set...
# 11  need grab base64-encoded representation viewst...

# %%
max(length)
# Out:
# 7683

# %%
np.quantile(length,0.9)
# Out:
# 266.0

# %%
new_df.to_csv('preprocessed_data.csv',index=False)
